# %%
import numpy as np
import random
import math

# Definición de la función mapeo
def mapeo(x, y, nr, nc, cscala):
    r = max(0, min(nr - round(y / cscala), nr - 1))
    c = max(0, min(round(x / cscala), nc - 1))
    return r, c

# Función para cargar la matriz desde un archivo .npy
def cargar_matriz(file_path):
    return np.load(file_path)

# Función que implementa la búsqueda codiciosa
def busqueda_codiciosa(matriz, posicion_inicial, limite_diferencia=2.0):
    filas, columnas = matriz.shape
    x, y = posicion_inicial
    trayectoria = [(x, y)]  # Almacena la trayectoria del explorador
    altura_actual = matriz[x, y]
    print(f"Posición inicial: ({x}, {y}), Altura inicial: {altura_actual} metros")

    while True:
        # Obtener los vecinos válidos (8-vecinos)
        vecinos = [(x+dx, y+dy) for dx in [-1, 0, 1] for dy in [-1, 0, 1] if (dx != 0 or dy != 0)]
        vecinos_validos = [(vx, vy) for vx, vy in vecinos if 0 <= vx < filas and 0 <= vy < columnas]

        # Seleccionar el vecino con menor altura cuya diferencia sea menor a 2 metros
        menor_vecino = None

        for vx, vy in vecinos_validos:
            altura_vecino = matriz[vx, vy]
            if altura_vecino < altura_actual and abs(altura_actual - altura_vecino) <= limite_diferencia:
                if menor_vecino is None or altura_vecino < matriz[menor_vecino[0], menor_vecino[1]]:
                    menor_vecino = (vx, vy)

        # Si no hay vecino válido, salir del bucle
        if menor_vecino is None:
            print("No se encontró un vecino con una altura menor y dentro del límite de diferencia.")
            break

        # Moverse al vecino con menor altura
        x, y = menor_vecino
        altura_actual = matriz[x, y]
        trayectoria.append((x, y))

        # Imprimir el movimiento
        print(f"Movimiento a: ({x}, {y}), Altura: {altura_actual} metros")

    return trayectoria, matriz[x, y]

# Función que implementa el recocido simulado
def recocido_simulado(matriz, posicion_inicial, limite_diferencia=2.0, temperatura_inicial=100, enfriamiento=0.99):
    filas, columnas = matriz.shape
    x, y = posicion_inicial
    trayectoria = [(x, y)]  # Almacena la trayectoria del explorador
    temperatura = temperatura_inicial
    altura_actual = matriz[x, y]
    print(f"Posición inicial: ({x}, {y}), Altura inicial: {altura_actual} metros")

    while temperatura > 1:
        # Obtener los vecinos válidos (8-vecinos)
        vecinos = [(x+dx, y+dy) for dx in [-1, 0, 1] for dy in [-1, 0, 1] if (dx != 0 or dy != 0)]
        vecinos_validos = [(vx, vy) for vx, vy in vecinos if 0 <= vx < filas and 0 <= vy < columnas]

        # Seleccionar un vecino al azar
        vx, vy = random.choice(vecinos_validos)
        altura_vecino = matriz[vx, vy]

        # Si la nueva posición es mejor, moverse
        if altura_vecino < altura_actual and abs(altura_actual - altura_vecino) <= limite_diferencia:
            x, y = vx, vy
            altura_actual = matriz[x, y]
        else:
            # Aceptar un peor movimiento según la probabilidad del recocido simulado
            diferencia_altura = abs(altura_vecino - altura_actual)
            if diferencia_altura <= limite_diferencia and random.uniform(0, 1) < math.exp(-diferencia_altura / temperatura):
                x, y = vx, vy
                altura_actual = matriz[x, y]

        trayectoria.append((x, y))

        # Imprimir el movimiento
        print(f"Movimiento a: ({x}, {y}), Altura: {altura_actual} metros, Temperatura: {temperatura}")

        # Reducir la temperatura
        temperatura *= enfriamiento

    return trayectoria, matriz[x, y]

# Pruebas de los algoritmos en varias posiciones con el mapeo
def pruebas_algoritmos(file_path, cscala=10.045):
    # Cargar la matriz
    matriz = cargar_matriz(file_path)
    nr, nc = matriz.shape  # Número de filas y columnas en la matriz

    # Posiciones de prueba (en metros)
    posiciones_metros = [
        (3200, 5000),  # Posición cercana al centro
        (3700, 4800),  # Posición 1 cercana al fondo
        (6000, 6000),  # Posición 2 cercana al fondo
        (1000, 2000),  # Posición 1 lejana
        (3000, 9000),  # Posición 2 lejana
        (7000, 5000)   # Posición aleatoria
    ]

    for i, (pos_x, pos_y) in enumerate(posiciones_metros):
        # Usar la función mapeo para obtener los índices en la matriz
        posicion_inicial = mapeo(pos_x, pos_y, nr, nc, cscala)
        print(f"\n===== Prueba {i+1}: Posición Inicial (metros): ({pos_x}, {pos_y}) =====")

        print("\n===== Búsqueda Codiciosa =====")
        trayectoria_codiciosa, altura_final_codiciosa = busqueda_codiciosa(matriz, posicion_inicial)
        print(f"Búsqueda codiciosa finalizó en: {trayectoria_codiciosa[-1]} con una altura de: {altura_final_codiciosa} metros\n")

        print("===== Recocido Simulado =====")
        trayectoria_recocido, altura_final_recocido = recocido_simulado(matriz, posicion_inicial)
        print(f"Recocido simulado finalizó en: {trayectoria_recocido[-1]} con una altura de: {altura_final_recocido} metros")

# Llamar la función de prueba
file_path = '/content/crater_map.npy'  # Reemplaza con la ruta correcta
pruebas_algoritmos(file_path)
# Out:
# ===== Prueba 1: Posición Inicial (metros): (3200, 5000) =====
#
# ===== Búsqueda Codiciosa =====
# Posición inicial: (579, 319), Altura inicial: 19.622644042968968 metros
# Movimiento a: (579, 318), Altura: 18.09316162109397 metros
# Movimiento a: (579, 317), Altura: 16.88699951171897 metros
# Movimiento a: (579, 316), Altura: 15.028312988281469 metros
# Movimiento a: (580, 315), Altura: 13.053227539062718 metros
# Movimiento a: (581, 314), Altura: 11.285727539062718 metros
# Movimiento a: (582, 313), Altura: 9.371701660156468 metros
# Movimiento a: (583, 312), Altura: 7.786967773437718 metros
# Movimiento a: (584, 311), Altura: 6.731242675781468 metros
# Movimiento a: (585, 310), Altura: 6.163105468750218 metros
# Movimiento a: (584, 309), Altura: 5.372785644531469 metros
# Movimiento a: (583, 308), Altura: 4.125615234375219 metros
# Movimiento a: (584, 307), Altura: 3.3430371093752185 metros
# Movimiento a: (585, 306), Altura: 3.1147460937502185 metros
# Movimiento a: (585, 305), Altura: 2.757001953125218 metros
# Movimiento a: (586, 304), Altura: 2.5858740234377184 metros
# Movimiento a: (585, 303), Altura: 2.5730126953127184 metros
# Movimiento a: (584, 302), Altura: 1.9160937500002182 metros
# Movimiento a: (584, 301), Altura: 1.3097705078127182 metros
# No se encontró un vecino con una altura menor y dentro del límite de diferencia.
# Búsqueda codiciosa finalizó en: (584, 301) con una altura de: 1.3097705078127182 metros
#
# ===== Recocido Simulado =====
# Posición inicial: (579, 319), Altura inicial: 19.622644042968968 metros
# Movimiento a: (578, 319), Altura: 20.311806640625218 metros, Temperatura: 100
# Movimiento a: (577, 320), Altura: 22.31070556640647 metros, Temperatura: 99.0
# Movimiento a: (576, 319), Altura: 21.942687988281467 metros, Temperatura: 98.01
# Movimiento a: (575, 319), Altura: 22.70355468750022 metros, Temperatura: 97.0299
# Movimiento a: (576, 320), Altura: 23.07340087890647 metros, Temperatura: 96.059601
# Movimiento a: (577, 320), Altura: 22.31070556640647 metros, Temperatura: 95.09900499
# Movimiento a: (578, 319), Altura: 20.311806640625218 metros, Temperatura: 94.1480149401
# Movimiento a: (577, 318), Altura: 19.412529296875217 metros, Temperatura: 93.206534790699
# Movimiento a: (577, 319), Altura: 20.69291992187522 metros, Temperatura: 92.27446944279201
# Movimiento a: (577, 319), Altura: 20.69291992187522 metros, Temperatura: 91.35172474836409
# Movimiento a: (577, 319), Altura: 20.69291992187522 metros, Temperatura: 90.43820750088045
# Movimiento a: (577, 319), Altura: 20.69291992187522 metros, Temperatura: 89.53382542587164
# Movimiento a: (577, 319), Altura: 20.69291992187522 metros, Temperatura: 88.63848717161292
# Movimiento a: (577, 318), Altura: 19.412529296875217 metros, Temperatura: 87.75210229989679
# Movimiento a: (577, 318), Altura: 19.412529296875217 metros, Temperatura: 86.87458127689783
# Movimiento a: (576, 318), Altura: 20.664270019531468 metros, Temperatura: 86.00583546412885
# Movimiento a: (576, 317), Altura: 19.23011230468772 metros, Temperatura: 85.14577710948755
# Movimiento a: (575, 317), Altura: 20.896936035156468 metros, Temperatura: 84.29431933839268
# Movimiento a: (575, 317), Altura: 20.896936035156468 metros, Temperatura: 83.45137614500875
# Movimiento a: (575, 318), Altura: 21.96947265625022 metros, Temperatura: 82.61686238355867
# Movimiento a: (575, 318), Altura: 21.96947265625022 metros, Temperatura: 81.79069375972308
# Movimiento a: (576, 319), Altura: 21.942687988281467 metros, Temperatura: 80.97278682212585
# Movimiento a: (575, 320), Altura: 23.697849121093967 metros, Temperatura: 80.1630589539046
# Movimiento a: (576, 319), Altura: 21.942687988281467 metros, Temperatura: 79.36142836436555
# Movimiento a: (575, 319), Altura: 22.70355468750022 metros, Temperatura: 78.56781408072189
# Movimiento a: (574, 319), Altura: 23.48341308593772 metros, Temperatura: 77.78213593991467
# Movimiento a: (575, 320), Altura: 23.697849121093967 metros, Temperatura: 77.00431458051553
# Movimiento a: (576, 319), Altura: 21.942687988281467 metros, Temperatura: 76.23427143471037
# Movimiento a: (576, 320), Altura: 23.07340087890647 metros, Temperatura: 75.47192872036327
# Movimiento a: (575, 319), Altura: 22.70355468750022 metros, Temperatura: 74.71720943315964
# Movimiento a: (574, 318), Altura: 22.375122070312717 metros, Temperatura: 73.97003733882804
# Movimiento a: (574, 317), Altura: 21.37137451171897 metros, Temperatura: 73.23033696543976
# Movimiento a: (573, 317), Altura: 21.70301025390647 metros, Temperatura: 72.49803359578536
# Movimiento a: (574, 317), Altura: 21.37137451171897 metros, Temperatura: 71.7730532598275
# Movimiento a: (573, 318), Altura: 22.460476074218967 metros, Temperatura: 71.05532272722922
# Movimiento a: (572, 317), Altura: 22.27407714843772 metros, Temperatura: 70.34476949995693
# Movimiento a: (571, 318), Altura: 23.834689941406467 metros, Temperatura: 69.64132180495736
# Movimiento a: (570, 317), Altura: 23.52709472656272 metros, Temperatura: 68.94490858690779
# Movimiento a: (569, 317), Altura: 24.11660644531272 metros, Temperatura: 68.25545950103871
# Movimiento a: (570, 318), Altura: 24.441711425781467 metros, Temperatura: 67.57290490602833
# Movimiento a: (571, 319), Altura: 24.70759033203147 metros, Temperatura: 66.89717585696805
# Movimiento a: (570, 319), Altura: 25.52691894531272 metros, Temperatura: 66.22820409839836
# Movimiento a: (570, 319), Altura: 25.52691894531272 metros, Temperatura: 65.56592205741438
# Movimiento a: (570, 318), Altura: 24.441711425781467 metros, Temperatura: 64.91026283684023
# Movimiento a: (571, 318), Altura: 23.834689941406467 metros, Temperatura: 64.26116020847184
# Movimiento a: (572, 318), Altura: 23.07285888671897 metros, Temperatura: 63.618548606387115
# Movimiento a: (571, 318), Altura: 23.834689941406467 metros, Temperatura: 62.98236312032324
# Movimiento a: (570, 319), Altura: 25.52691894531272 metros, Temperatura: 62.35253948912001
# Movimiento a: (571, 318), Altura: 23.834689941406467 metros, Temperatura: 61.72901409422881
# Movimiento a: (570, 319), Altura: 25.52691894531272 metros, Temperatura: 61.11172395328652
# Movimiento a: (569, 318), Altura: 25.30171142578147 metros, Temperatura: 60.500606713753655
# Movimiento a: (569, 317), Altura: 24.11660644531272 metros, Temperatura: 59.89560064661612
# Movimiento a: (568, 317), Altura: 24.881779785156468 metros, Temperatura: 59.29664464014996
# Movimiento a: (567, 317), Altura: 25.935422363281468 metros, Temperatura: 58.70367819374846
# Movimiento a: (566, 316), Altura: 26.73605957031272 metros, Temperatura: 58.116641411810974
# Movimiento a: (566, 317), Altura: 26.906892089843968 metros, Temperatura: 57.535474997692866
# Movimiento a: (566, 316), Altura: 26.73605957031272 metros, Temperatura: 56.960120247715935
# Movimiento a: (567, 316), Altura: 25.592189941406467 metros, Temperatura: 56.390519045238776
# Movimiento a: (568, 315), Altura: 23.744934082031467 metros, Temperatura: 55.82661385478639
# Movimiento a: (569, 314), Altura: 21.90505859375022 metros, Temperatura: 55.26834771623852
# Movimiento a: (568, 314), Altura: 22.63550781250022 metros, Temperatura: 54.71566423907614
# Movimiento a: (568, 314), Altura: 22.63550781250022 metros, Temperatura: 54.16850759668538
# Movimiento a: (569, 314), Altura: 21.90505859375022 metros, Temperatura: 53.62682252071853
# Movimiento a: (570, 314), Altura: 21.59300537109397 metros, Temperatura: 53.09055429551134
# Movimiento a: (569, 314), Altura: 21.90505859375022 metros, Temperatura: 52.55964875255623
# Movimiento a: (569, 315), Altura: 22.91799804687522 metros, Temperatura: 52.03405226503067
# Movimiento a: (570, 316), Altura: 22.58988525390647 metros, Temperatura: 51.51371174238036
# Movimiento a: (571, 316), Altura: 22.27663330078147 metros, Temperatura: 50.998574624956554
# Movimiento a: (572, 317), Altura: 22.27407714843772 metros, Temperatura: 50.488588878706985
# Movimiento a: (573, 316), Altura: 21.224948730468967 metros, Temperatura: 49.98370298991991
# Movimiento a: (574, 316), Altura: 20.16150634765647 metros, Temperatura: 49.483865960020715
# Movimiento a: (574, 317), Altura: 21.37137451171897 metros, Temperatura: 48.98902730042051
# Movimiento a: (574, 318), Altura: 22.375122070312717 metros, Temperatura: 48.4991370274163
# Movimiento a: (574, 319), Altura: 23.48341308593772 metros, Temperatura: 48.01414565714214
# Movimiento a: (574, 319), Altura: 23.48341308593772 metros, Temperatura: 47.53400420057071
# Movimiento a: (574, 318), Altura: 22.375122070312717 metros, Temperatura: 47.05866415856501
# Movimiento a: (573, 319), Altura: 23.67718017578147 metros, Temperatura: 46.58807751697936
# Movimiento a: (572, 318), Altura: 23.07285888671897 metros, Temperatura: 46.12219674180957
# Movimiento a: (571, 319), Altura: 24.70759033203147 metros, Temperatura: 45.66097477439147
# Movimiento a: (571, 320), Altura: 25.93801025390647 metros, Temperatura: 45.20436502664755
# Movimiento a: (570, 319), Altura: 25.52691894531272 metros, Temperatura: 44.752321376381076
# Movimiento a: (570, 318), Altura: 24.441711425781467 metros, Temperatura: 44.30479816261727
# Movimiento a: (569, 318), Altura: 25.30171142578147 metros, Temperatura: 43.861750180991095
# Movimiento a: (569, 319), Altura: 26.37909912109397 metros, Temperatura: 43.42313267918119
# Movimiento a: (570, 320), Altura: 26.72802246093772 metros, Temperatura: 42.98890135238938
# Movimiento a: (571, 320), Altura: 25.93801025390647 metros, Temperatura: 42.559012338865486
# Movimiento a: (570, 319), Altura: 25.52691894531272 metros, Temperatura: 42.133422215476834
# Movimiento a: (570, 320), Altura: 26.72802246093772 metros, Temperatura: 41.712087993322065
# Movimiento a: (569, 319), Altura: 26.37909912109397 metros, Temperatura: 41.29496711338884
# Movimiento a: (569, 318), Altura: 25.30171142578147 metros, Temperatura: 40.882017442254956
# Movimiento a: (570, 318), Altura: 24.441711425781467 metros, Temperatura: 40.473197267832404
# Movimiento a: (569, 317), Altura: 24.11660644531272 metros, Temperatura: 40.06846529515408
# Movimiento a: (568, 316), Altura: 24.10109130859397 metros, Temperatura: 39.66778064220254
# Movimiento a: (569, 315), Altura: 22.91799804687522 metros, Temperatura: 39.27110283578051
# Movimiento a: (569, 316), Altura: 23.17819091796897 metros, Temperatura: 38.8783918074227
# Movimiento a: (568, 315), Altura: 23.744934082031467 metros, Temperatura: 38.48960788934848
# Movimiento a: (569, 315), Altura: 22.91799804687522 metros, Temperatura: 38.104711810454994
# Movimiento a: (570, 314), Altura: 21.59300537109397 metros, Temperatura: 37.72366469235045
# Movimiento a: (571, 313), Altura: 20.56359375000022 metros, Temperatura: 37.34642804542694
# Movimiento a: (570, 314), Altura: 21.59300537109397 metros, Temperatura: 36.97296376497267
# Movimiento a: (571, 313), Altura: 20.56359375000022 metros, Temperatura: 36.60323412732294
# Movimiento a: (570, 313), Altura: 20.46106201171897 metros, Temperatura: 36.23720178604971
# Movimiento a: (569, 314), Altura: 21.90505859375022 metros, Temperatura: 35.874829768189215
# Movimiento a: (568, 315), Altura: 23.744934082031467 metros, Temperatura: 35.516081470507324
# Movimiento a: (567, 316), Altura: 25.592189941406467 metros, Temperatura: 35.16092065580225
# Movimiento a: (568, 317), Altura: 24.881779785156468 metros, Temperatura: 34.80931144924423
# Movimiento a: (568, 316), Altura: 24.10109130859397 metros, Temperatura: 34.461218334751784
# Movimiento a: (568, 317), Altura: 24.881779785156468 metros, Temperatura: 34.11660615140427
# Movimiento a: (568, 318), Altura: 25.98612792968772 metros, Temperatura: 33.775440089890225
# Movimiento a: (568, 318), Altura: 25.98612792968772 metros, Temperatura: 33.43768568899132
# Movimiento a: (569, 319), Altura: 26.37909912109397 metros, Temperatura: 33.10330883210141
# Movimiento a: (569, 319), Altura: 26.37909912109397 metros, Temperatura: 32.7722757437804
# Movimiento a: (570, 318), Altura: 24.441711425781467 metros, Temperatura: 32.44455298634259
# Movimiento a: (569, 318), Altura: 25.30171142578147 metros, Temperatura: 32.12010745647917
# Movimiento a: (569, 319), Altura: 26.37909912109397 metros, Temperatura: 31.798906381914374
# Movimiento a: (570, 318), Altura: 24.441711425781467 metros, Temperatura: 31.48091731809523
# Movimiento a: (571, 318), Altura: 23.834689941406467 metros, Temperatura: 31.16610814491428
# Movimiento a: (572, 318), Altura: 23.07285888671897 metros, Temperatura: 30.854447063465138
# Movimiento a: (573, 318), Altura: 22.460476074218967 metros, Temperatura: 30.545902592830487
# Movimiento a: (574, 319), Altura: 23.48341308593772 metros, Temperatura: 30.240443566902183
# Movimiento a: (575, 320), Altura: 23.697849121093967 metros, Temperatura: 29.93803913123316
# Movimiento a: (575, 319), Altura: 22.70355468750022 metros, Temperatura: 29.638658739920828
# Movimiento a: (574, 318), Altura: 22.375122070312717 metros, Temperatura: 29.34227215252162
# Movimiento a: (573, 318), Altura: 22.460476074218967 metros, Temperatura: 29.048849430996402
# Movimiento a: (572, 318), Altura: 23.07285888671897 metros, Temperatura: 28.758360936686437
# Movimiento a: (572, 319), Altura: 23.918664550781468 metros, Temperatura: 28.47077732731957
# Movimiento a: (572, 318), Altura: 23.07285888671897 metros, Temperatura: 28.186069554046373
# Movimiento a: (573, 317), Altura: 21.70301025390647 metros, Temperatura: 27.90420885850591
# Movimiento a: (574, 318), Altura: 22.375122070312717 metros, Temperatura: 27.625166769920853
# Movimiento a: (575, 319), Altura: 22.70355468750022 metros, Temperatura: 27.348915102221643
# Movimiento a: (574, 318), Altura: 22.375122070312717 metros, Temperatura: 27.075425951199424
# Movimiento a: (574, 319), Altura: 23.48341308593772 metros, Temperatura: 26.804671691687428
# Movimiento a: (574, 318), Altura: 22.375122070312717 metros, Temperatura: 26.536624974770554
# Movimiento a: (573, 317), Altura: 21.70301025390647 metros, Temperatura: 26.271258725022847
# Movimiento a: (572, 317), Altura: 22.27407714843772 metros, Temperatura: 26.00854613777262
# Movimiento a: (571, 317), Altura: 22.94043701171897 metros, Temperatura: 25.748460676394892
# Movimiento a: (572, 318), Altura: 23.07285888671897 metros, Temperatura: 25.490976069630943
# Movimiento a: (573, 318), Altura: 22.460476074218967 metros, Temperatura: 25.23606630893463
# Movimiento a: (572, 318), Altura: 23.07285888671897 metros, Temperatura: 24.983705645845284
# Movimiento a: (573, 318), Altura: 22.460476074218967 metros, Temperatura: 24.73386858938683
# Movimiento a: (572, 317), Altura: 22.27407714843772 metros, Temperatura: 24.48652990349296
# Movimiento a: (573, 317), Altura: 21.70301025390647 metros, Temperatura: 24.24166460445803
# Movimiento a: (573, 318), Altura: 22.460476074218967 metros, Temperatura: 23.99924795841345
# Movimiento a: (573, 318), Altura: 22.460476074218967 metros, Temperatura: 23.759255478829314
# Movimiento a: (573, 319), Altura: 23.67718017578147 metros, Temperatura: 23.52166292404102
# Movimiento a: (572, 319), Altura: 23.918664550781468 metros, Temperatura: 23.28644629480061
# Movimiento a: (573, 318), Altura: 22.460476074218967 metros, Temperatura: 23.053581831852604
# Movimiento a: (572, 318), Altura: 23.07285888671897 metros, Temperatura: 22.82304601353408
# Movimiento a: (571, 317), Altura: 22.94043701171897 metros, Temperatura: 22.59481555339874
# Movimiento a: (571, 316), Altura: 22.27663330078147 metros, Temperatura: 22.36886739786475
# Movimiento a: (570, 317), Altura: 23.52709472656272 metros, Temperatura: 22.145178723886104
# Movimiento a: (571, 318), Altura: 23.834689941406467 metros, Temperatura: 21.923726936647242
# Movimiento a: (570, 318), Altura: 24.441711425781467 metros, Temperatura: 21.704489667280768
# Movimiento a: (571, 318), Altura: 23.834689941406467 metros, Temperatura: 21.48744477060796
# Movimiento a: (570, 318), Altura: 24.441711425781467 metros, Temperatura: 21.27257032290188
# Movimiento a: (570, 319), Altura: 25.52691894531272 metros, Temperatura: 21.059844619672862
# Movimiento a: (570, 318), Altura: 24.441711425781467 metros, Temperatura: 20.849246173476132
# Movimiento a: (569, 318), Altura: 25.30171142578147 metros, Temperatura: 20.64075371174137
# Movimiento a: (570, 317), Altura: 23.52709472656272 metros, Temperatura: 20.434346174623958
# Movimiento a: (571, 316), Altura: 22.27663330078147 metros, Temperatura: 20.230002712877717
# Movimiento a: (571, 315), Altura: 22.173698730468967 metros, Temperatura: 20.027702685748938
# Movimiento a: (570, 315), Altura: 22.246520996093967 metros, Temperatura: 19.82742565889145
# Movimiento a: (569, 316), Altura: 23.17819091796897 metros, Temperatura: 19.629151402302536
# Movimiento a: (570, 315), Altura: 22.246520996093967 metros, Temperatura: 19.43285988827951
# Movimiento a: (570, 316), Altura: 22.58988525390647 metros, Temperatura: 19.238531289396715
# Movimiento a: (571, 316), Altura: 22.27663330078147 metros, Temperatura: 19.046145976502746
# Movimiento a: (570, 315), Altura: 22.246520996093967 metros, Temperatura: 18.855684516737718
# Movimiento a: (569, 314), Altura: 21.90505859375022 metros, Temperatura: 18.66712767157034
# Movimiento a: (570, 314), Altura: 21.59300537109397 metros, Temperatura: 18.480456394854638
# Movimiento a: (569, 313), Altura: 20.80336669921897 metros, Temperatura: 18.295651830906092
# Movimiento a: (569, 313), Altura: 20.80336669921897 metros, Temperatura: 18.11269531259703
# Movimiento a: (570, 312), Altura: 19.70849853515647 metros, Temperatura: 17.931568359471058
# Movimiento a: (571, 311), Altura: 19.046166992187718 metros, Temperatura: 17.752252675876345
# Movimiento a: (571, 312), Altura: 20.01331298828147 metros, Temperatura: 17.57473014911758
# Movimiento a: (571, 312), Altura: 20.01331298828147 metros, Temperatura: 17.398982847626407
# Movimiento a: (571, 312), Altura: 20.01331298828147 metros, Temperatura: 17.22499301915014
# Movimiento a: (570, 312), Altura: 19.70849853515647 metros, Temperatura: 17.05274308895864
# Movimiento a: (571, 312), Altura: 20.01331298828147 metros, Temperatura: 16.882215658069054
# Movimiento a: (572, 312), Altura: 20.634331054687717 metros, Temperatura: 16.713393501488362
# Movimiento a: (573, 313), Altura: 22.424584960937718 metros, Temperatura: 16.546259566473477
# Movimiento a: (573, 314), Altura: 22.76112548828147 metros, Temperatura: 16.380796970808742
# Movimiento a: (572, 314), Altura: 22.029343261718967 metros, Temperatura: 16.216989001100654
# Movimiento a: (571, 315), Altura: 22.173698730468967 metros, Temperatura: 16.054819111089646
# Movimiento a: (572, 315), Altura: 22.082275390625217 metros, Temperatura: 15.89427091997875
# Movimiento a: (572, 314), Altura: 22.029343261718967 metros, Temperatura: 15.735328210778961
# Movimiento a: (573, 314), Altura: 22.76112548828147 metros, Temperatura: 15.577974928671171
# Movimiento a: (573, 315), Altura: 21.824550781250217 metros, Temperatura: 15.42219517938446
# Movimiento a: (572, 315), Altura: 22.082275390625217 metros, Temperatura: 15.267973227590614
# Movimiento a: (573, 316), Altura: 21.224948730468967 metros, Temperatura: 15.115293495314708
# Movimiento a: (572, 316), Altura: 21.792473144531467 metros, Temperatura: 14.96414056036156
# Movimiento a: (571, 317), Altura: 22.94043701171897 metros, Temperatura: 14.814499154757945
# Movimiento a: (571, 318), Altura: 23.834689941406467 metros, Temperatura: 14.666354163210364
# Movimiento a: (570, 317), Altura: 23.52709472656272 metros, Temperatura: 14.519690621578262
# Movimiento a: (569, 317), Altura: 24.11660644531272 metros, Temperatura: 14.374493715362478
# Movimiento a: (568, 316), Altura: 24.10109130859397 metros, Temperatura: 14.230748778208852
# Movimiento a: (569, 317), Altura: 24.11660644531272 metros, Temperatura: 14.088441290426763
# Movimiento a: (568, 318), Altura: 25.98612792968772 metros, Temperatura: 13.947556877522496
# Movimiento a: (567, 318), Altura: 26.952058105468968 metros, Temperatura: 13.808081308747271
# Movimiento a: (567, 317), Altura: 25.935422363281468 metros, Temperatura: 13.670000495659798
# Movimiento a: (568, 317), Altura: 24.881779785156468 metros, Temperatura: 13.5333004907032
# Movimiento a: (567, 317), Altura: 25.935422363281468 metros, Temperatura: 13.397967485796167
# Movimiento a: (566, 318), Altura: 27.875671386718967 metros, Temperatura: 13.263987810938206
# Movimiento a: (567, 319), Altura: 28.153977050781467 metros, Temperatura: 13.131347932828824
# Movimiento a: (568, 319), Altura: 27.20484863281272 metros, Temperatura: 13.000034453500536
# Movimiento a: (567, 319), Altura: 28.153977050781467 metros, Temperatura: 12.87003410896553
# Movimiento a: (568, 320), Altura: 28.50603759765647 metros, Temperatura: 12.741333767875876
# Movimiento a: (568, 320), Altura: 28.50603759765647 metros, Temperatura: 12.613920430197117
# Movimiento a: (568, 319), Altura: 27.20484863281272 metros, Temperatura: 12.487781225895146
# Movimiento a: (569, 319), Altura: 26.37909912109397 metros, Temperatura: 12.362903413636195
# Movimiento a: (570, 319), Altura: 25.52691894531272 metros, Temperatura: 12.239274379499832
# Movimiento a: (571, 320), Altura: 25.93801025390647 metros, Temperatura: 12.116881635704834
# Movimiento a: (571, 320), Altura: 25.93801025390647 metros, Temperatura: 11.995712819347785
# Movimiento a: (571, 320), Altura: 25.93801025390647 metros, Temperatura: 11.875755691154307
# Movimiento a: (571, 320), Altura: 25.93801025390647 metros, Temperatura: 11.756998134242764
# Movimiento a: (571, 321), Altura: 27.24677490234397 metros, Temperatura: 11.639428152900336
# Movimiento a: (571, 321), Altura: 27.24677490234397 metros, Temperatura: 11.523033871371332
# Movimiento a: (572, 321), Altura: 26.531540527343967 metros, Temperatura: 11.407803532657619
# Movimiento a: (572, 321), Altura: 26.531540527343967 metros, Temperatura: 11.293725497331042
# Movimiento a: (571, 321), Altura: 27.24677490234397 metros, Temperatura: 11.180788242357732
# Movimiento a: (570, 321), Altura: 28.18712402343772 metros, Temperatura: 11.068980359934155
# Movimiento a: (569, 320), Altura: 27.710224609375217 metros, Temperatura: 10.958290556334813
# Movimiento a: (570, 321), Altura: 28.18712402343772 metros, Temperatura: 10.848707650771464
# Movimiento a: (571, 322), Altura: 28.74284667968772 metros, Temperatura: 10.74022057426375
# Movimiento a: (571, 321), Altura: 27.24677490234397 metros, Temperatura: 10.632818368521113
# Movimiento a: (570, 320), Altura: 26.72802246093772 metros, Temperatura: 10.526490184835902
# Movimiento a: (569, 319), Altura: 26.37909912109397 metros, Temperatura: 10.421225282987542
# Movimiento a: (569, 319), Altura: 26.37909912109397 metros, Temperatura: 10.317013030157668
# Movimiento a: (568, 318), Altura: 25.98612792968772 metros, Temperatura: 10.213842899856092
# Movimiento a: (567, 317), Altura: 25.935422363281468 metros, Temperatura: 10.11170447085753
# Movimiento a: (568, 316), Altura: 24.10109130859397 metros, Temperatura: 10.010587426148955
# Movimiento a: (569, 315), Altura: 22.91799804687522 metros, Temperatura: 9.910481551887466
# Movimiento a: (568, 315), Altura: 23.744934082031467 metros, Temperatura: 9.811376736368592
# Movimiento a: (567, 314), Altura: 23.134274902343968 metros, Temperatura: 9.713262969004907
# Movimiento a: (567, 314), Altura: 23.134274902343968 metros, Temperatura: 9.616130339314857
# Movimiento a: (568, 315), Altura: 23.744934082031467 metros, Temperatura: 9.519969035921708
# Movimiento a: (569, 316), Altura: 23.17819091796897 metros, Temperatura: 9.42476934556249
# Movimiento a: (570, 317), Altura: 23.52709472656272 metros, Temperatura: 9.330521652106865
# Movimiento a: (569, 316), Altura: 23.17819091796897 metros, Temperatura: 9.237216435585797
# Movimiento a: (568, 315), Altura: 23.744934082031467 metros, Temperatura: 9.144844271229939
# Movimiento a: (567, 315), Altura: 24.87070800781272 metros, Temperatura: 9.053395828517639
# Movimiento a: (566, 314), Altura: 23.74132080078147 metros, Temperatura: 8.962861870232462
# Movimiento a: (566, 315), Altura: 25.38560058593772 metros, Temperatura: 8.873233251530138
# Movimiento a: (566, 314), Altura: 23.74132080078147 metros, Temperatura: 8.784500919014837
# Movimiento a: (567, 313), Altura: 21.96060058593772 metros, Temperatura: 8.696655909824688
# Movimiento a: (568, 313), Altura: 21.454990234375217 metros, Temperatura: 8.609689350726441
# Movimiento a: (569, 314), Altura: 21.90505859375022 metros, Temperatura: 8.523592457219177
# Movimiento a: (570, 314), Altura: 21.59300537109397 metros, Temperatura: 8.438356532646985
# Movimiento a: (571, 314), Altura: 21.544396972656468 metros, Temperatura: 8.353972967320516
# Movimiento a: (572, 315), Altura: 22.082275390625217 metros, Temperatura: 8.27043323764731
# Movimiento a: (572, 314), Altura: 22.029343261718967 metros, Temperatura: 8.187728905270838
# Movimiento a: (573, 315), Altura: 21.824550781250217 metros, Temperatura: 8.105851616218128
# Movimiento a: (573, 314), Altura: 22.76112548828147 metros, Temperatura: 8.024793100055946
# Movimiento a: (573, 313), Altura: 22.424584960937718 metros, Temperatura: 7.944545169055387
# Movimiento a: (573, 313), Altura: 22.424584960937718 metros, Temperatura: 7.865099717364833
# Movimiento a: (573, 313), Altura: 22.424584960937718 metros, Temperatura: 7.786448720191185
# Movimiento a: (573, 313), Altura: 22.424584960937718 metros, Temperatura: 7.708584232989273
# Movimiento a: (572, 313), Altura: 22.06889160156272 metros, Temperatura: 7.63149839065938
# Movimiento a: (572, 313), Altura: 22.06889160156272 metros, Temperatura: 7.5551834067527865
# Movimiento a: (572, 313), Altura: 22.06889160156272 metros, Temperatura: 7.479631572685259
# Movimiento a: (572, 313), Altura: 22.06889160156272 metros, Temperatura: 7.404835256958406
# Movimiento a: (573, 314), Altura: 22.76112548828147 metros, Temperatura: 7.330786904388821
# Movimiento a: (572, 314), Altura: 22.029343261718967 metros, Temperatura: 7.257479035344933
# Movimiento a: (572, 313), Altura: 22.06889160156272 metros, Temperatura: 7.1849042449914835
# Movimiento a: (572, 312), Altura: 20.634331054687717 metros, Temperatura: 7.1130552025415685
# Movimiento a: (572, 312), Altura: 20.634331054687717 metros, Temperatura: 7.041924650516153
# Movimiento a: (572, 312), Altura: 20.634331054687717 metros, Temperatura: 6.971505404010991
# Movimiento a: (571, 313), Altura: 20.56359375000022 metros, Temperatura: 6.901790349970882
# Movimiento a: (570, 312), Altura: 19.70849853515647 metros, Temperatura: 6.832772446471173
# Movimiento a: (570, 311), Altura: 19.25318847656272 metros, Temperatura: 6.764444722006462
# Movimiento a: (571, 310), Altura: 18.49879394531272 metros, Temperatura: 6.696800274786397
# Movimiento a: (571, 309), Altura: 18.62592529296897 metros, Temperatura: 6.6298322720385325
# Movimiento a: (571, 310), Altura: 18.49879394531272 metros, Temperatura: 6.563533949318147
# Movimiento a: (570, 309), Altura: 19.62481201171897 metros, Temperatura: 6.497898609824966
# Movimiento a: (569, 310), Altura: 19.543144531250217 metros, Temperatura: 6.432919623726716
# Movimiento a: (569, 311), Altura: 19.680615234375217 metros, Temperatura: 6.3685904274894485
# Movimiento a: (568, 310), Altura: 19.96734130859397 metros, Temperatura: 6.304904523214554
# Movimiento a: (568, 310), Altura: 19.96734130859397 metros, Temperatura: 6.2418554779824085
# Movimiento a: (567, 310), Altura: 20.48598388671897 metros, Temperatura: 6.1794369232025845
# Movimiento a: (566, 310), Altura: 21.33376953125022 metros, Temperatura: 6.117642553970558
# Movimiento a: (567, 309), Altura: 20.393952636718968 metros, Temperatura: 6.056466128430853
# Movimiento a: (567, 309), Altura: 20.393952636718968 metros, Temperatura: 5.9959014671465445
# Movimiento a: (568, 308), Altura: 20.23442382812522 metros, Temperatura: 5.935942452475079
# Movimiento a: (568, 309), Altura: 20.59875732421897 metros, Temperatura: 5.8765830279503275
# Movimiento a: (569, 310), Altura: 19.543144531250217 metros, Temperatura: 5.817817197670824
# Movimiento a: (568, 310), Altura: 19.96734130859397 metros, Temperatura: 5.759639025694116
# Movimiento a: (567, 309), Altura: 20.393952636718968 metros, Temperatura: 5.7020426354371745
# Movimiento a: (567, 310), Altura: 20.48598388671897 metros, Temperatura: 5.645022209082803
# Movimiento a: (566, 309), Altura: 21.48036132812522 metros, Temperatura: 5.588571986991974
# Movimiento a: (565, 309), Altura: 23.33998779296897 metros, Temperatura: 5.532686267122054
# Movimiento a: (565, 308), Altura: 22.381088867187717 metros, Temperatura: 5.477359404450834
# Movimiento a: (566, 307), Altura: 20.673676757812718 metros, Temperatura: 5.422585810406325
# Movimiento a: (566, 307), Altura: 20.673676757812718 metros, Temperatura: 5.368359952302262
# Movimiento a: (565, 306), Altura: 21.49812500000022 metros, Temperatura: 5.314676352779239
# Movimiento a: (566, 307), Altura: 20.673676757812718 metros, Temperatura: 5.261529589251447
# Movimiento a: (567, 306), Altura: 19.868352050781468 metros, Temperatura: 5.208914293358933
# Movimiento a: (568, 307), Altura: 19.977226562500217 metros, Temperatura: 5.156825150425344
# Movimiento a: (567, 306), Altura: 19.868352050781468 metros, Temperatura: 5.10525689892109
# Movimiento a: (568, 306), Altura: 20.326713867187717 metros, Temperatura: 5.0542043299318795
# Movimiento a: (569, 305), Altura: 18.717419433593967 metros, Temperatura: 5.003662286632561
# Movimiento a: (569, 305), Altura: 18.717419433593967 metros, Temperatura: 4.953625663766235
# Movimiento a: (569, 305), Altura: 18.717419433593967 metros, Temperatura: 4.9040894071285726
# Movimiento a: (568, 305), Altura: 19.29282958984397 metros, Temperatura: 4.8550485130572865
# Movimiento a: (569, 305), Altura: 18.717419433593967 metros, Temperatura: 4.806498027926714
# Movimiento a: (568, 306), Altura: 20.326713867187717 metros, Temperatura: 4.758433047647447
# Movimiento a: (568, 305), Altura: 19.29282958984397 metros, Temperatura: 4.710848717170973
# Movimiento a: (567, 304), Altura: 18.50684326171897 metros, Temperatura: 4.663740229999263
# Movimiento a: (567, 304), Altura: 18.50684326171897 metros, Temperatura: 4.61710282769927
# Movimiento a: (567, 303), Altura: 17.349975585937717 metros, Temperatura: 4.570931799422278
# Movimiento a: (567, 303), Altura: 17.349975585937717 metros, Temperatura: 4.525222481428055
# Movimiento a: (567, 302), Altura: 16.712346191406468 metros, Temperatura: 4.4799702566137745
# Movimiento a: (567, 301), Altura: 16.507602539062717 metros, Temperatura: 4.4351705540476365
# Movimiento a: (566, 301), Altura: 17.998906250000218 metros, Temperatura: 4.39081884850716
# Movimiento a: (565, 301), Altura: 19.28242675781272 metros, Temperatura: 4.346910660022088
# Movimiento a: (564, 301), Altura: 20.94677978515647 metros, Temperatura: 4.303441553421867
# Movimiento a: (564, 302), Altura: 21.034714355468967 metros, Temperatura: 4.260407137887648
# Movimiento a: (564, 302), Altura: 21.034714355468967 metros, Temperatura: 4.217803066508771
# Movimiento a: (565, 302), Altura: 19.73184814453147 metros, Temperatura: 4.175625035843683
# Movimiento a: (565, 303), Altura: 20.06649658203147 metros, Temperatura: 4.133868785485246
# Movimiento a: (565, 303), Altura: 20.06649658203147 metros, Temperatura: 4.0925300976303935
# Movimiento a: (566, 304), Altura: 19.59730712890647 metros, Temperatura: 4.05160479665409
# Movimiento a: (567, 305), Altura: 19.44319335937522 metros, Temperatura: 4.011088748687548
# Movimiento a: (566, 306), Altura: 20.402145996093967 metros, Temperatura: 3.970977861200673
# Movimiento a: (565, 305), Altura: 20.91131835937522 metros, Temperatura: 3.9312680825886663
# Movimiento a: (565, 304), Altura: 20.59387451171897 metros, Temperatura: 3.8919554017627798
# Movimiento a: (565, 305), Altura: 20.91131835937522 metros, Temperatura: 3.853035847745152
# Movimiento a: (565, 305), Altura: 20.91131835937522 metros, Temperatura: 3.8145054892677006
# Movimiento a: (566, 304), Altura: 19.59730712890647 metros, Temperatura: 3.7763604343750234
# Movimiento a: (566, 304), Altura: 19.59730712890647 metros, Temperatura: 3.7385968300312733
# Movimiento a: (565, 305), Altura: 20.91131835937522 metros, Temperatura: 3.7012108617309605
# Movimiento a: (566, 304), Altura: 19.59730712890647 metros, Temperatura: 3.664198753113651
# Movimiento a: (565, 303), Altura: 20.06649658203147 metros, Temperatura: 3.6275567655825145
# Movimiento a: (566, 303), Altura: 18.742722167968967 metros, Temperatura: 3.591281197926689
# Movimiento a: (565, 303), Altura: 20.06649658203147 metros, Temperatura: 3.555368385947422
# Movimiento a: (565, 302), Altura: 19.73184814453147 metros, Temperatura: 3.519814702087948
# Movimiento a: (564, 303), Altura: 21.47078125000022 metros, Temperatura: 3.4846165550670687
# Movimiento a: (563, 303), Altura: 23.14390869140647 metros, Temperatura: 3.449770389516398
# Movimiento a: (564, 303), Altura: 21.47078125000022 metros, Temperatura: 3.415272685621234
# Movimiento a: (565, 304), Altura: 20.59387451171897 metros, Temperatura: 3.3811199587650216
# Movimiento a: (565, 304), Altura: 20.59387451171897 metros, Temperatura: 3.347308759177371
# Movimiento a: (565, 304), Altura: 20.59387451171897 metros, Temperatura: 3.3138356715855974
# Movimiento a: (565, 303), Altura: 20.06649658203147 metros, Temperatura: 3.2806973148697414
# Movimiento a: (566, 302), Altura: 18.154194335937717 metros, Temperatura: 3.247890341721044
# Movimiento a: (566, 302), Altura: 18.154194335937717 metros, Temperatura: 3.2154114383038332
# Movimiento a: (567, 301), Altura: 16.507602539062717 metros, Temperatura: 3.183257323920795
# Movimiento a: (566, 302), Altura: 18.154194335937717 metros, Temperatura: 3.1514247506815867
# Movimiento a: (565, 303), Altura: 20.06649658203147 metros, Temperatura: 3.1199105031747707
# Movimiento a: (564, 304), Altura: 22.048317871093968 metros, Temperatura: 3.088711398143023
# Movimiento a: (564, 304), Altura: 22.048317871093968 metros, Temperatura: 3.0578242841615926
# Movimiento a: (565, 305), Altura: 20.91131835937522 metros, Temperatura: 3.0272460413199767
# Movimiento a: (564, 305), Altura: 22.33987304687522 metros, Temperatura: 2.996973580906777
# Movimiento a: (565, 304), Altura: 20.59387451171897 metros, Temperatura: 2.967003845097709
# Movimiento a: (566, 304), Altura: 19.59730712890647 metros, Temperatura: 2.9373338066467323
# Movimiento a: (565, 305), Altura: 20.91131835937522 metros, Temperatura: 2.907960468580265
# Movimiento a: (566, 306), Altura: 20.402145996093967 metros, Temperatura: 2.8788808638944623
# Movimiento a: (565, 305), Altura: 20.91131835937522 metros, Temperatura: 2.8500920552555176
# Movimiento a: (564, 306), Altura: 22.873203125000217 metros, Temperatura: 2.8215911347029623
# Movimiento a: (563, 305), Altura: 24.00681152343772 metros, Temperatura: 2.7933752233559326
# Movimiento a: (562, 305), Altura: 25.79824707031272 metros, Temperatura: 2.765441471122373
# Movimiento a: (562, 304), Altura: 25.254353027343967 metros, Temperatura: 2.7377870564111495
# Movimiento a: (562, 304), Altura: 25.254353027343967 metros, Temperatura: 2.710409185847038
# Movimiento a: (562, 304), Altura: 25.254353027343967 metros, Temperatura: 2.6833050939885674
# Movimiento a: (562, 303), Altura: 24.879604492187717 metros, Temperatura: 2.656472043048682
# Movimiento a: (562, 303), Altura: 24.879604492187717 metros, Temperatura: 2.629907322618195
# Movimiento a: (562, 303), Altura: 24.879604492187717 metros, Temperatura: 2.603608249392013
# Movimiento a: (562, 302), Altura: 24.49428466796897 metros, Temperatura: 2.577572166898093
# Movimiento a: (562, 301), Altura: 23.95392089843772 metros, Temperatura: 2.551796445229112
# Movimiento a: (562, 300), Altura: 23.39217285156272 metros, Temperatura: 2.526278480776821
# Movimiento a: (561, 299), Altura: 24.91354980468772 metros, Temperatura: 2.501015695969053
# Movimiento a: (561, 298), Altura: 24.28056152343772 metros, Temperatura: 2.4760055390093623
# Movimiento a: (561, 299), Altura: 24.91354980468772 metros, Temperatura: 2.4512454836192688
# Movimiento a: (560, 299), Altura: 26.72557373046897 metros, Temperatura: 2.426733028783076
# Movimiento a: (559, 298), Altura: 28.10064941406272 metros, Temperatura: 2.402465698495245
# Movimiento a: (559, 297), Altura: 27.33609619140647 metros, Temperatura: 2.3784410415102926
# Movimiento a: (559, 298), Altura: 28.10064941406272 metros, Temperatura: 2.3546566310951897
# Movimiento a: (559, 297), Altura: 27.33609619140647 metros, Temperatura: 2.3311100647842378
# Movimiento a: (559, 298), Altura: 28.10064941406272 metros, Temperatura: 2.307798964136395
# Movimiento a: (559, 297), Altura: 27.33609619140647 metros, Temperatura: 2.2847209744950314
# Movimiento a: (559, 297), Altura: 27.33609619140647 metros, Temperatura: 2.261873764750081
# Movimiento a: (560, 298), Altura: 26.295964355468968 metros, Temperatura: 2.23925502710258
# Movimiento a: (560, 298), Altura: 26.295964355468968 metros, Temperatura: 2.2168624768315546
# Movimiento a: (560, 298), Altura: 26.295964355468968 metros, Temperatura: 2.194693852063239
# Movimiento a: (559, 298), Altura: 28.10064941406272 metros, Temperatura: 2.1727469135426065
# Movimiento a: (559, 299), Altura: 28.80399169921897 metros, Temperatura: 2.1510194444071806
# Movimiento a: (560, 300), Altura: 27.418618164062718 metros, Temperatura: 2.129509249963109
# Movimiento a: (560, 300), Altura: 27.418618164062718 metros, Temperatura: 2.108214157463478
# Movimiento a: (560, 300), Altura: 27.418618164062718 metros, Temperatura: 2.087132015888843
# Movimiento a: (560, 299), Altura: 26.72557373046897 metros, Temperatura: 2.0662606957299547
# Movimiento a: (561, 300), Altura: 25.346367187500217 metros, Temperatura: 2.045598088772655
# Movimiento a: (561, 301), Altura: 25.982963867187717 metros, Temperatura: 2.0251421078849283
# Movimiento a: (562, 302), Altura: 24.49428466796897 metros, Temperatura: 2.004890686806079
# Movimiento a: (563, 303), Altura: 23.14390869140647 metros, Temperatura: 1.9848417799380185
# Movimiento a: (562, 302), Altura: 24.49428466796897 metros, Temperatura: 1.9649933621386382
# Movimiento a: (562, 302), Altura: 24.49428466796897 metros, Temperatura: 1.9453434285172517
# Movimiento a: (563, 302), Altura: 22.754921875000218 metros, Temperatura: 1.9258899942320793
# Movimiento a: (563, 302), Altura: 22.754921875000218 metros, Temperatura: 1.9066310942897584
# Movimiento a: (564, 303), Altura: 21.47078125000022 metros, Temperatura: 1.8875647833468607
# Movimiento a: (564, 302), Altura: 21.034714355468967 metros, Temperatura: 1.868689135513392
# Movimiento a: (565, 303), Altura: 20.06649658203147 metros, Temperatura: 1.8500022441582582
# Movimiento a: (565, 303), Altura: 20.06649658203147 metros, Temperatura: 1.8315022217166756
# Movimiento a: (566, 302), Altura: 18.154194335937717 metros, Temperatura: 1.8131871994995088
# Movimiento a: (567, 301), Altura: 16.507602539062717 metros, Temperatura: 1.7950553275045138
# Movimiento a: (568, 302), Altura: 15.040639648437718 metros, Temperatura: 1.7771047742294686
# Movimiento a: (569, 303), Altura: 14.644143066406468 metros, Temperatura: 1.7593337264871738
# Movimiento a: (569, 303), Altura: 14.644143066406468 metros, Temperatura: 1.741740389222302
# Movimiento a: (570, 304), Altura: 15.14846679687522 metros, Temperatura: 1.724322985330079
# Movimiento a: (570, 305), Altura: 16.457478027343967 metros, Temperatura: 1.7070797554767783
# Movimiento a: (570, 305), Altura: 16.457478027343967 metros, Temperatura: 1.6900089579220106
# Movimiento a: (570, 305), Altura: 16.457478027343967 metros, Temperatura: 1.6731088683427904
# Movimiento a: (570, 305), Altura: 16.457478027343967 metros, Temperatura: 1.6563777796593624
# Movimiento a: (570, 305), Altura: 16.457478027343967 metros, Temperatura: 1.6398140018627687
# Movimiento a: (570, 305), Altura: 16.457478027343967 metros, Temperatura: 1.623415861844141
# Movimiento a: (569, 304), Altura: 16.264145507812717 metros, Temperatura: 1.6071817032256996
# Movimiento a: (570, 304), Altura: 15.14846679687522 metros, Temperatura: 1.5911098861934427
# Movimiento a: (571, 305), Altura: 13.287331542968968 metros, Temperatura: 1.5751987873315083
# Movimiento a: (571, 304), Altura: 13.026347656250218 metros, Temperatura: 1.5594467994581933
# Movimiento a: (571, 304), Altura: 13.026347656250218 metros, Temperatura: 1.5438523314636114
# Movimiento a: (571, 303), Altura: 12.634572753906468 metros, Temperatura: 1.5284138081489753
# Movimiento a: (571, 303), Altura: 12.634572753906468 metros, Temperatura: 1.5131296700674854
# Movimiento a: (571, 302), Altura: 11.326298828125218 metros, Temperatura: 1.4979983733668105
# Movimiento a: (571, 302), Altura: 11.326298828125218 metros, Temperatura: 1.4830183896331424
# Movimiento a: (571, 302), Altura: 11.326298828125218 metros, Temperatura: 1.468188205736811
# Movimiento a: (571, 301), Altura: 10.000322265625218 metros, Temperatura: 1.4535063236794428
# Movimiento a: (571, 302), Altura: 11.326298828125218 metros, Temperatura: 1.4389712604426483
# Movimiento a: (570, 302), Altura: 12.012756347656468 metros, Temperatura: 1.4245815478382218
# Movimiento a: (571, 302), Altura: 11.326298828125218 metros, Temperatura: 1.4103357323598396
# Movimiento a: (570, 301), Altura: 10.964086914062719 metros, Temperatura: 1.396232375036241
# Movimiento a: (570, 301), Altura: 10.964086914062719 metros, Temperatura: 1.3822700512858788
# Movimiento a: (569, 301), Altura: 12.602077636718969 metros, Temperatura: 1.36844735077302
# Movimiento a: (569, 302), Altura: 13.361240234375218 metros, Temperatura: 1.3547628772652898
# Movimiento a: (568, 301), Altura: 14.566535644531468 metros, Temperatura: 1.341215248492637
# Movimiento a: (569, 301), Altura: 12.602077636718969 metros, Temperatura: 1.3278030960077105
# Movimiento a: (570, 301), Altura: 10.964086914062719 metros, Temperatura: 1.3145250650476334
# Movimiento a: (570, 301), Altura: 10.964086914062719 metros, Temperatura: 1.301379814397157
# Movimiento a: (571, 301), Altura: 10.000322265625218 metros, Temperatura: 1.2883660162531856
# Movimiento a: (572, 301), Altura: 9.515705566406469 metros, Temperatura: 1.2754823560906536
# Movimiento a: (572, 300), Altura: 8.095173339843969 metros, Temperatura: 1.2627275325297471
# Movimiento a: (573, 299), Altura: 6.351166992187718 metros, Temperatura: 1.2501002572044497
# Movimiento a: (574, 299), Altura: 6.045317382812718 metros, Temperatura: 1.2375992546324053
# Movimiento a: (575, 299), Altura: 4.5393676757814685 metros, Temperatura: 1.2252232620860812
# Movimiento a: (576, 298), Altura: 3.5296533203127183 metros, Temperatura: 1.2129710294652205
# Movimiento a: (575, 297), Altura: 3.888835449218968 metros, Temperatura: 1.2008413191705682
# Movimiento a: (575, 297), Altura: 3.888835449218968 metros, Temperatura: 1.1888329059788625
# Movimiento a: (576, 297), Altura: 3.215031738281468 metros, Temperatura: 1.1769445769190738
# Movimiento a: (577, 298), Altura: 3.234990234375218 metros, Temperatura: 1.165175131149883
# Movimiento a: (578, 297), Altura: 1.8192968750002183 metros, Temperatura: 1.1535233798383842
# Movimiento a: (577, 296), Altura: 2.7441503906252183 metros, Temperatura: 1.1419881460400003
# Movimiento a: (577, 297), Altura: 2.2900146484377184 metros, Temperatura: 1.1305682645796002
# Movimiento a: (577, 296), Altura: 2.7441503906252183 metros, Temperatura: 1.1192625819338042
# Movimiento a: (577, 297), Altura: 2.2900146484377184 metros, Temperatura: 1.1080699561144662
# Movimiento a: (576, 298), Altura: 3.5296533203127183 metros, Temperatura: 1.0969892565533215
# Movimiento a: (576, 298), Altura: 3.5296533203127183 metros, Temperatura: 1.0860193639877882
# Movimiento a: (577, 297), Altura: 2.2900146484377184 metros, Temperatura: 1.0751591703479102
# Movimiento a: (577, 297), Altura: 2.2900146484377184 metros, Temperatura: 1.0644075786444311
# Movimiento a: (577, 297), Altura: 2.2900146484377184 metros, Temperatura: 1.0537635028579868
# Movimiento a: (578, 296), Altura: 1.5280175781252183 metros, Temperatura: 1.0432258678294068
# Movimiento a: (579, 296), Altura: 1.0929150390627183 metros, Temperatura: 1.0327936091511127
# Movimiento a: (579, 296), Altura: 1.0929150390627183 metros, Temperatura: 1.0224656730596016
# Movimiento a: (580, 297), Altura: 0.9502441406252182 metros, Temperatura: 1.0122410163290056
# Movimiento a: (581, 298), Altura: 0.8547412109377183 metros, Temperatura: 1.0021186061657157
# Recocido simulado finalizó en: (581, 298) con una altura de: 0.8547412109377183 metros
#
# ===== Prueba 2: Posición Inicial (metros): (3700, 4800) =====
#
# ===== Búsqueda Codiciosa =====
# Posición inicial: (599, 368), Altura inicial: 101.19197021484396 metros
# Movimiento a: (598, 367), Altura: 100.75139404296897 metros
# Movimiento a: (598, 366), Altura: 100.52006591796896 metros
# Movimiento a: (597, 365), Altura: 100.01589599609397 metros
# Movimiento a: (597, 364), Altura: 99.03332275390648 metros
# Movimiento a: (598, 363), Altura: 97.49534179687522 metros
# Movimiento a: (599, 362), Altura: 95.72848388671896 metros
# Movimiento a: (599, 361), Altura: 94.55046142578146 metros
# Movimiento a: (598, 360), Altura: 93.84218261718772 metros
# Movimiento a: (597, 359), Altura: 93.36778808593772 metros
# Movimiento a: (596, 358), Altura: 91.49738769531272 metros
# Movimiento a: (595, 357), Altura: 89.66456298828147 metros
# Movimiento a: (596, 357), Altura: 88.61055908203147 metros
# No se encontró un vecino con una altura menor y dentro del límite de diferencia.
# Búsqueda codiciosa finalizó en: (596, 357) con una altura de: 88.61055908203147 metros
#
# ===== Recocido Simulado =====
# Posición inicial: (599, 368), Altura inicial: 101.19197021484396 metros
# Movimiento a: (599, 368), Altura: 101.19197021484396 metros, Temperatura: 100
# Movimiento a: (598, 367), Altura: 100.75139404296897 metros, Temperatura: 99.0
# Movimiento a: (599, 367), Altura: 100.87795410156272 metros, Temperatura: 98.01
# Movimiento a: (598, 367), Altura: 100.75139404296897 metros, Temperatura: 97.0299
# Movimiento a: (598, 368), Altura: 100.77539306640647 metros, Temperatura: 96.059601
# Movimiento a: (599, 369), Altura: 101.89305419921897 metros, Temperatura: 95.09900499
# Movimiento a: (598, 369), Altura: 101.06401611328147 metros, Temperatura: 94.1480149401
# Movimiento a: (597, 368), Altura: 100.62526855468772 metros, Temperatura: 93.206534790699
# Movimiento a: (598, 367), Altura: 100.75139404296897 metros, Temperatura: 92.27446944279201
# Movimiento a: (597, 368), Altura: 100.62526855468772 metros, Temperatura: 91.35172474836409
# Movimiento a: (598, 367), Altura: 100.75139404296897 metros, Temperatura: 90.43820750088045
# Movimiento a: (599, 367), Altura: 100.87795410156272 metros, Temperatura: 89.53382542587164
# Movimiento a: (599, 368), Altura: 101.19197021484396 metros, Temperatura: 88.63848717161292
# Movimiento a: (598, 369), Altura: 101.06401611328147 metros, Temperatura: 87.75210229989679
# Movimiento a: (598, 370), Altura: 101.76241699218772 metros, Temperatura: 86.87458127689783
# Movimiento a: (597, 369), Altura: 100.84754638671897 metros, Temperatura: 86.00583546412885
# Movimiento a: (597, 370), Altura: 101.59067626953147 metros, Temperatura: 85.14577710948755
# Movimiento a: (596, 370), Altura: 101.34265136718771 metros, Temperatura: 84.29431933839268
# Movimiento a: (597, 370), Altura: 101.59067626953147 metros, Temperatura: 83.45137614500875
# Movimiento a: (596, 369), Altura: 100.88051513671897 metros, Temperatura: 82.61686238355867
# Movimiento a: (595, 370), Altura: 101.10276611328146 metros, Temperatura: 81.79069375972308
# Movimiento a: (595, 371), Altura: 101.54823730468772 metros, Temperatura: 80.97278682212585
# Movimiento a: (594, 371), Altura: 101.55046875000022 metros, Temperatura: 80.1630589539046
# Movimiento a: (594, 372), Altura: 103.25868652343772 metros, Temperatura: 79.36142836436555
# Movimiento a: (594, 372), Altura: 103.25868652343772 metros, Temperatura: 78.56781408072189
# Movimiento a: (594, 371), Altura: 101.55046875000022 metros, Temperatura: 77.78213593991467
# Movimiento a: (594, 371), Altura: 101.55046875000022 metros, Temperatura: 77.00431458051553
# Movimiento a: (594, 370), Altura: 101.06193603515646 metros, Temperatura: 76.23427143471037
# Movimiento a: (593, 371), Altura: 101.48200195312522 metros, Temperatura: 75.47192872036327
# Movimiento a: (592, 370), Altura: 100.44949707031272 metros, Temperatura: 74.71720943315964
# Movimiento a: (592, 371), Altura: 100.94152343750022 metros, Temperatura: 73.97003733882804
# Movimiento a: (593, 371), Altura: 101.48200195312522 metros, Temperatura: 73.23033696543976
# Movimiento a: (592, 372), Altura: 102.36315917968771 metros, Temperatura: 72.49803359578536
# Movimiento a: (593, 371), Altura: 101.48200195312522 metros, Temperatura: 71.7730532598275
# Movimiento a: (593, 372), Altura: 102.87084960937521 metros, Temperatura: 71.05532272722922
# ...
# Movimiento a: (574, 708), Altura: -1.0 metros, Temperatura: 7.5551834067527865
# Movimiento a: (573, 707), Altura: -1.0 metros, Temperatura: 7.479631572685259
# Movimiento a: (574, 706), Altura: -1.0 metros, Temperatura: 7.404835256958406
# Movimiento a: (573, 705), Altura: -1.0 metros, Temperatura: 7.330786904388821
# Movimiento a: (573, 706), Altura: -1.0 metros, Temperatura: 7.257479035344933
# Movimiento a: (572, 705), Altura: -1.0 metros, Temperatura: 7.1849042449914835
# Movimiento a: (571, 706), Altura: -1.0 metros, Temperatura: 7.1130552025415685
# Movimiento a: (572, 707), Altura: -1.0 metros, Temperatura: 7.041924650516153
# Movimiento a: (571, 706), Altura: -1.0 metros, Temperatura: 6.971505404010991
# Movimiento a: (571, 705), Altura: -1.0 metros, Temperatura: 6.901790349970882
# Movimiento a: (571, 706), Altura: -1.0 metros, Temperatura: 6.832772446471173
# Movimiento a: (571, 705), Altura: -1.0 metros, Temperatura: 6.764444722006462
# Movimiento a: (571, 704), Altura: -1.0 metros, Temperatura: 6.696800274786397
# Movimiento a: (572, 704), Altura: -1.0 metros, Temperatura: 6.6298322720385325
# Movimiento a: (571, 705), Altura: -1.0 metros, Temperatura: 6.563533949318147
# Movimiento a: (572, 704), Altura: -1.0 metros, Temperatura: 6.497898609824966
# Movimiento a: (572, 705), Altura: -1.0 metros, Temperatura: 6.432919623726716
# Movimiento a: (571, 704), Altura: -1.0 metros, Temperatura: 6.3685904274894485
# Movimiento a: (571, 703), Altura: -1.0 metros, Temperatura: 6.304904523214554
# Movimiento a: (570, 704), Altura: -1.0 metros, Temperatura: 6.2418554779824085
# Movimiento a: (571, 705), Altura: -1.0 metros, Temperatura: 6.1794369232025845
# Movimiento a: (572, 704), Altura: -1.0 metros, Temperatura: 6.117642553970558
# Movimiento a: (571, 705), Altura: -1.0 metros, Temperatura: 6.056466128430853
# Movimiento a: (570, 706), Altura: -1.0 metros, Temperatura: 5.9959014671465445
# Movimiento a: (571, 707), Altura: -1.0 metros, Temperatura: 5.935942452475079
# Movimiento a: (570, 708), Altura: -1.0 metros, Temperatura: 5.8765830279503275
# Movimiento a: (570, 707), Altura: -1.0 metros, Temperatura: 5.817817197670824
# Movimiento a: (571, 706), Altura: -1.0 metros, Temperatura: 5.759639025694116
# Movimiento a: (571, 707), Altura: -1.0 metros, Temperatura: 5.7020426354371745
# Movimiento a: (570, 706), Altura: -1.0 metros, Temperatura: 5.645022209082803
# Movimiento a: (571, 705), Altura: -1.0 metros, Temperatura: 5.588571986991974
# Movimiento a: (570, 705), Altura: -1.0 metros, Temperatura: 5.532686267122054
# Movimiento a: (569, 704), Altura: -1.0 metros, Temperatura: 5.477359404450834
# Movimiento a: (568, 704), Altura: -1.0 metros, Temperatura: 5.422585810406325
# Movimiento a: (569, 704), Altura: -1.0 metros, Temperatura: 5.368359952302262
# Movimiento a: (569, 703), Altura: -1.0 metros, Temperatura: 5.314676352779239
# Movimiento a: (568, 704), Altura: -1.0 metros, Temperatura: 5.261529589251447
# Movimiento a: (567, 704), Altura: -1.0 metros, Temperatura: 5.208914293358933
# Movimiento a: (567, 703), Altura: -1.0 metros, Temperatura: 5.156825150425344
# Movimiento a: (568, 702), Altura: -1.0 metros, Temperatura: 5.10525689892109
# Movimiento a: (568, 701), Altura: -1.0 metros, Temperatura: 5.0542043299318795
# Movimiento a: (567, 702), Altura: -1.0 metros, Temperatura: 5.003662286632561
# Movimiento a: (567, 701), Altura: -1.0 metros, Temperatura: 4.953625663766235
# Movimiento a: (567, 700), Altura: -1.0 metros, Temperatura: 4.9040894071285726
# Movimiento a: (566, 700), Altura: -1.0 metros, Temperatura: 4.8550485130572865
# Movimiento a: (565, 699), Altura: -1.0 metros, Temperatura: 4.806498027926714
# Movimiento a: (564, 698), Altura: -1.0 metros, Temperatura: 4.758433047647447
# Movimiento a: (563, 699), Altura: -1.0 metros, Temperatura: 4.710848717170973
# Movimiento a: (564, 700), Altura: -1.0 metros, Temperatura: 4.663740229999263
# Movimiento a: (563, 701), Altura: -1.0 metros, Temperatura: 4.61710282769927
# Movimiento a: (563, 700), Altura: -1.0 metros, Temperatura: 4.570931799422278
# Movimiento a: (564, 701), Altura: -1.0 metros, Temperatura: 4.525222481428055
# Movimiento a: (563, 701), Altura: -1.0 metros, Temperatura: 4.4799702566137745
# Movimiento a: (562, 701), Altura: -1.0 metros, Temperatura: 4.4351705540476365
# Movimiento a: (562, 700), Altura: -1.0 metros, Temperatura: 4.39081884850716
# Movimiento a: (563, 699), Altura: -1.0 metros, Temperatura: 4.346910660022088
# Movimiento a: (564, 700), Altura: -1.0 metros, Temperatura: 4.303441553421867
# Movimiento a: (565, 701), Altura: -1.0 metros, Temperatura: 4.260407137887648
# Movimiento a: (566, 702), Altura: -1.0 metros, Temperatura: 4.217803066508771
# Movimiento a: (565, 701), Altura: -1.0 metros, Temperatura: 4.175625035843683
# Movimiento a: (564, 701), Altura: -1.0 metros, Temperatura: 4.133868785485246
# Movimiento a: (565, 701), Altura: -1.0 metros, Temperatura: 4.0925300976303935
# Movimiento a: (566, 700), Altura: -1.0 metros, Temperatura: 4.05160479665409
# Movimiento a: (567, 700), Altura: -1.0 metros, Temperatura: 4.011088748687548
# Movimiento a: (566, 700), Altura: -1.0 metros, Temperatura: 3.970977861200673
# Movimiento a: (565, 701), Altura: -1.0 metros, Temperatura: 3.9312680825886663
# Movimiento a: (564, 700), Altura: -1.0 metros, Temperatura: 3.8919554017627798
# Movimiento a: (564, 699), Altura: -1.0 metros, Temperatura: 3.853035847745152
# Movimiento a: (563, 700), Altura: -1.0 metros, Temperatura: 3.8145054892677006
# Movimiento a: (563, 701), Altura: -1.0 metros, Temperatura: 3.7763604343750234
# Movimiento a: (563, 702), Altura: -1.0 metros, Temperatura: 3.7385968300312733
# Movimiento a: (562, 702), Altura: -1.0 metros, Temperatura: 3.7012108617309605
# Movimiento a: (563, 702), Altura: -1.0 metros, Temperatura: 3.664198753113651
# Movimiento a: (564, 703), Altura: -1.0 metros, Temperatura: 3.6275567655825145
# Movimiento a: (565, 703), Altura: -1.0 metros, Temperatura: 3.591281197926689
# Movimiento a: (564, 703), Altura: -1.0 metros, Temperatura: 3.555368385947422
# Movimiento a: (564, 702), Altura: -1.0 metros, Temperatura: 3.519814702087948
# Movimiento a: (564, 701), Altura: -1.0 metros, Temperatura: 3.4846165550670687
# Movimiento a: (564, 700), Altura: -1.0 metros, Temperatura: 3.449770389516398
# Movimiento a: (565, 700), Altura: -1.0 metros, Temperatura: 3.415272685621234
# Movimiento a: (564, 701), Altura: -1.0 metros, Temperatura: 3.3811199587650216
# Movimiento a: (565, 700), Altura: -1.0 metros, Temperatura: 3.347308759177371
# Movimiento a: (566, 699), Altura: -1.0 metros, Temperatura: 3.3138356715855974
# Movimiento a: (565, 698), Altura: -1.0 metros, Temperatura: 3.2806973148697414
# Movimiento a: (564, 697), Altura: -1.0 metros, Temperatura: 3.247890341721044
# Movimiento a: (565, 697), Altura: -1.0 metros, Temperatura: 3.2154114383038332
# Movimiento a: (564, 698), Altura: -1.0 metros, Temperatura: 3.183257323920795
# Movimiento a: (564, 697), Altura: -1.0 metros, Temperatura: 3.1514247506815867
# Movimiento a: (563, 697), Altura: -1.0 metros, Temperatura: 3.1199105031747707
# Movimiento a: (564, 696), Altura: -1.0 metros, Temperatura: 3.088711398143023
# Movimiento a: (565, 696), Altura: -1.0 metros, Temperatura: 3.0578242841615926
# Movimiento a: (565, 695), Altura: -1.0 metros, Temperatura: 3.0272460413199767
# Movimiento a: (566, 694), Altura: -1.0 metros, Temperatura: 2.996973580906777
# Movimiento a: (567, 693), Altura: -1.0 metros, Temperatura: 2.967003845097709
# Movimiento a: (566, 693), Altura: -1.0 metros, Temperatura: 2.9373338066467323
# Movimiento a: (565, 692), Altura: -1.0 metros, Temperatura: 2.907960468580265
# Movimiento a: (564, 693), Altura: -1.0 metros, Temperatura: 2.8788808638944623
# Movimiento a: (563, 693), Altura: -1.0 metros, Temperatura: 2.8500920552555176
# Movimiento a: (563, 692), Altura: -1.0 metros, Temperatura: 2.8215911347029623
# Movimiento a: (562, 691), Altura: -1.0 metros, Temperatura: 2.7933752233559326
# Movimiento a: (561, 691), Altura: -1.0 metros, Temperatura: 2.765441471122373
# Movimiento a: (561, 690), Altura: -1.0 metros, Temperatura: 2.7377870564111495
# Movimiento a: (560, 690), Altura: -1.0 metros, Temperatura: 2.710409185847038
# Movimiento a: (561, 691), Altura: -1.0 metros, Temperatura: 2.6833050939885674
# Movimiento a: (561, 692), Altura: -1.0 metros, Temperatura: 2.656472043048682
# Movimiento a: (561, 691), Altura: -1.0 metros, Temperatura: 2.629907322618195
# Movimiento a: (560, 690), Altura: -1.0 metros, Temperatura: 2.603608249392013
# Movimiento a: (559, 691), Altura: -1.0 metros, Temperatura: 2.577572166898093
# Movimiento a: (558, 692), Altura: -1.0 metros, Temperatura: 2.551796445229112
# Movimiento a: (557, 692), Altura: -1.0 metros, Temperatura: 2.526278480776821
# Movimiento a: (557, 691), Altura: -1.0 metros, Temperatura: 2.501015695969053
# Movimiento a: (558, 691), Altura: -1.0 metros, Temperatura: 2.4760055390093623
# Movimiento a: (557, 690), Altura: -1.0 metros, Temperatura: 2.4512454836192688
# Movimiento a: (556, 691), Altura: -1.0 metros, Temperatura: 2.426733028783076
# Movimiento a: (557, 692), Altura: -1.0 metros, Temperatura: 2.402465698495245
# Movimiento a: (556, 691), Altura: -1.0 metros, Temperatura: 2.3784410415102926
# Movimiento a: (557, 691), Altura: -1.0 metros, Temperatura: 2.3546566310951897
# Movimiento a: (556, 692), Altura: -1.0 metros, Temperatura: 2.3311100647842378
# Movimiento a: (555, 692), Altura: -1.0 metros, Temperatura: 2.307798964136395
# Movimiento a: (556, 692), Altura: -1.0 metros, Temperatura: 2.2847209744950314
# Movimiento a: (557, 692), Altura: -1.0 metros, Temperatura: 2.261873764750081
# Movimiento a: (557, 693), Altura: -1.0 metros, Temperatura: 2.23925502710258
# Movimiento a: (557, 694), Altura: -1.0 metros, Temperatura: 2.2168624768315546
# Movimiento a: (558, 695), Altura: -1.0 metros, Temperatura: 2.194693852063239
# Movimiento a: (558, 696), Altura: -1.0 metros, Temperatura: 2.1727469135426065
# Movimiento a: (559, 697), Altura: -1.0 metros, Temperatura: 2.1510194444071806
# Movimiento a: (559, 696), Altura: -1.0 metros, Temperatura: 2.129509249963109
# Movimiento a: (559, 695), Altura: -1.0 metros, Temperatura: 2.108214157463478
# Movimiento a: (559, 694), Altura: -1.0 metros, Temperatura: 2.087132015888843
# Movimiento a: (558, 695), Altura: -1.0 metros, Temperatura: 2.0662606957299547
# Movimiento a: (559, 696), Altura: -1.0 metros, Temperatura: 2.045598088772655
# Movimiento a: (560, 696), Altura: -1.0 metros, Temperatura: 2.0251421078849283
# Movimiento a: (560, 697), Altura: -1.0 metros, Temperatura: 2.004890686806079
# Movimiento a: (559, 697), Altura: -1.0 metros, Temperatura: 1.9848417799380185
# Movimiento a: (559, 696), Altura: -1.0 metros, Temperatura: 1.9649933621386382
# Movimiento a: (560, 696), Altura: -1.0 metros, Temperatura: 1.9453434285172517
# Movimiento a: (561, 695), Altura: -1.0 metros, Temperatura: 1.9258899942320793
# Movimiento a: (562, 694), Altura: -1.0 metros, Temperatura: 1.9066310942897584
# Movimiento a: (562, 693), Altura: -1.0 metros, Temperatura: 1.8875647833468607
# Movimiento a: (562, 694), Altura: -1.0 metros, Temperatura: 1.868689135513392
# Movimiento a: (561, 694), Altura: -1.0 metros, Temperatura: 1.8500022441582582
# Movimiento a: (560, 693), Altura: -1.0 metros, Temperatura: 1.8315022217166756
# Movimiento a: (560, 692), Altura: -1.0 metros, Temperatura: 1.8131871994995088
# Movimiento a: (559, 693), Altura: -1.0 metros, Temperatura: 1.7950553275045138
# Movimiento a: (559, 692), Altura: -1.0 metros, Temperatura: 1.7771047742294686
# Movimiento a: (560, 691), Altura: -1.0 metros, Temperatura: 1.7593337264871738
# Movimiento a: (559, 690), Altura: -1.0 metros, Temperatura: 1.741740389222302
# Movimiento a: (560, 690), Altura: -1.0 metros, Temperatura: 1.724322985330079
# Movimiento a: (561, 689), Altura: -1.0 metros, Temperatura: 1.7070797554767783
# Movimiento a: (562, 690), Altura: -1.0 metros, Temperatura: 1.6900089579220106
# Movimiento a: (561, 689), Altura: -1.0 metros, Temperatura: 1.6731088683427904
# Movimiento a: (560, 688), Altura: -1.0 metros, Temperatura: 1.6563777796593624
# Movimiento a: (560, 687), Altura: -1.0 metros, Temperatura: 1.6398140018627687
# Movimiento a: (559, 688), Altura: -1.0 metros, Temperatura: 1.623415861844141
# Movimiento a: (558, 689), Altura: -1.0 metros, Temperatura: 1.6071817032256996
# Movimiento a: (557, 689), Altura: -1.0 metros, Temperatura: 1.5911098861934427
# Movimiento a: (558, 689), Altura: -1.0 metros, Temperatura: 1.5751987873315083
# Movimiento a: (557, 688), Altura: -1.0 metros, Temperatura: 1.5594467994581933
# Movimiento a: (558, 688), Altura: -1.0 metros, Temperatura: 1.5438523314636114
# Movimiento a: (559, 689), Altura: -1.0 metros, Temperatura: 1.5284138081489753
# Movimiento a: (560, 688), Altura: -1.0 metros, Temperatura: 1.5131296700674854
# Movimiento a: (559, 688), Altura: -1.0 metros, Temperatura: 1.4979983733668105
# Movimiento a: (560, 688), Altura: -1.0 metros, Temperatura: 1.4830183896331424
# Movimiento a: (561, 688), Altura: -1.0 metros, Temperatura: 1.468188205736811
# Movimiento a: (560, 689), Altura: -1.0 metros, Temperatura: 1.4535063236794428
# Movimiento a: (560, 688), Altura: -1.0 metros, Temperatura: 1.4389712604426483
# Movimiento a: (561, 687), Altura: -1.0 metros, Temperatura: 1.4245815478382218
# Movimiento a: (562, 687), Altura: -1.0 metros, Temperatura: 1.4103357323598396
# Movimiento a: (561, 688), Altura: -1.0 metros, Temperatura: 1.396232375036241
# Movimiento a: (560, 689), Altura: -1.0 metros, Temperatura: 1.3822700512858788
# Movimiento a: (561, 689), Altura: -1.0 metros, Temperatura: 1.36844735077302
# Movimiento a: (562, 690), Altura: -1.0 metros, Temperatura: 1.3547628772652898
# Movimiento a: (562, 691), Altura: -1.0 metros, Temperatura: 1.341215248492637
# Movimiento a: (561, 692), Altura: -1.0 metros, Temperatura: 1.3278030960077105
# Movimiento a: (560, 692), Altura: -1.0 metros, Temperatura: 1.3145250650476334
# Movimiento a: (561, 692), Altura: -1.0 metros, Temperatura: 1.301379814397157
# Movimiento a: (562, 692), Altura: -1.0 metros, Temperatura: 1.2883660162531856
# Movimiento a: (562, 691), Altura: -1.0 metros, Temperatura: 1.2754823560906536
# Movimiento a: (561, 692), Altura: -1.0 metros, Temperatura: 1.2627275325297471
# Movimiento a: (561, 691), Altura: -1.0 metros, Temperatura: 1.2501002572044497
# Movimiento a: (560, 692), Altura: -1.0 metros, Temperatura: 1.2375992546324053
# Movimiento a: (561, 691), Altura: -1.0 metros, Temperatura: 1.2252232620860812
# Movimiento a: (561, 692), Altura: -1.0 metros, Temperatura: 1.2129710294652205
# Movimiento a: (562, 691), Altura: -1.0 metros, Temperatura: 1.2008413191705682
# Movimiento a: (561, 690), Altura: -1.0 metros, Temperatura: 1.1888329059788625
# Movimiento a: (561, 689), Altura: -1.0 metros, Temperatura: 1.1769445769190738
# Movimiento a: (561, 690), Altura: -1.0 metros, Temperatura: 1.165175131149883
# Movimiento a: (562, 689), Altura: -1.0 metros, Temperatura: 1.1535233798383842
# Movimiento a: (563, 689), Altura: -1.0 metros, Temperatura: 1.1419881460400003
# Movimiento a: (563, 688), Altura: -1.0 metros, Temperatura: 1.1305682645796002
# Movimiento a: (562, 687), Altura: -1.0 metros, Temperatura: 1.1192625819338042
# Movimiento a: (563, 686), Altura: -1.0 metros, Temperatura: 1.1080699561144662
# Movimiento a: (564, 685), Altura: -1.0 metros, Temperatura: 1.0969892565533215
# Movimiento a: (563, 685), Altura: -1.0 metros, Temperatura: 1.0860193639877882
# Movimiento a: (564, 686), Altura: -1.0 metros, Temperatura: 1.0751591703479102
# Movimiento a: (563, 686), Altura: -1.0 metros, Temperatura: 1.0644075786444311
# Movimiento a: (563, 687), Altura: -1.0 metros, Temperatura: 1.0537635028579868
# Movimiento a: (562, 688), Altura: -1.0 metros, Temperatura: 1.0432258678294068
# Movimiento a: (563, 689), Altura: -1.0 metros, Temperatura: 1.0327936091511127
# Movimiento a: (562, 688), Altura: -1.0 metros, Temperatura: 1.0224656730596016
# Movimiento a: (562, 689), Altura: -1.0 metros, Temperatura: 1.0122410163290056
# Movimiento a: (562, 688), Altura: -1.0 metros, Temperatura: 1.0021186061657157
# Recocido simulado finalizó en: (562, 688) con una altura de: -1.0 metros
